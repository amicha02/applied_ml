# %% [markdown]
# # HW2-Prob 5: No Free Lunch!!

# %% [markdown]
# # problem 1

# %% [markdown]
# ## How to produce the data

# %%
import random
import numpy as np 
X = random.sample(range(0, 100000), 1000)
X_test = np.array(X[:200])
X_train = np.array(X[200:])
y = np.random.randint(2, size=1000)
y = np.where(y == 0, -1, 1)
y_test = y[:200]
y_train = y[200:]

# %% [markdown]
# ## accuracy = (true positives + true negatives)/all samples

# %%
all_sammples = 200

# %% [markdown]
# All unique integers that will be assinged to the X variable, will be randomized. Which means approximately there's a 50% chance that the number will be even, and a 50% chane that it will be odd. <br>Given that assumption, true negatives = 0, true positives = 0.5*200 = 100 <br> accuracy= 50%

# %% [markdown]
# Across the space of all possible integer values that we can get from minus infinity to infinity, for X, we'll have on average 50% of them being integers, and 50% of them being even.

# %% [markdown]
# # problem 2

# %% [markdown]
# The cardinality of the whole dataset is 1000 because we have 10000 unique integer numbers. In addition we have only 2 possible outcome in each row, therefore the number of true functions that can be utilized is $2^{1000}$

# %% [markdown]
# # problem 3

# %% [markdown]
# No prior assumptions means that the weights accross all functions are uniform. In this case, if we compute the accuracy of the g we chose above, on every one of these f, and averaged over all of them, the accuracy of g would be 50%.

# %% [markdown]
# # problem 4

# %% [markdown]
# Again, if the f is chosen at random and looked at our dataset, then we would still end up with 50% due to the uniformity of the weights across the f functions that map our inputs to our ys.
